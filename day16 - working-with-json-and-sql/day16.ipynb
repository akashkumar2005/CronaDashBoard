# %% [markdown]
# <a href="https://colab.research.google.com/github/akashkumar2005/CronaDashBoard/blob/main/day16%20-%20working-with-json-and-sql/day16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Woking with JSON

# %% [markdown]
# # 🚀 ML Revision Shortcut: GitHub to Google Colab Direct Open
#
# Jab bhi GitHub par koi `.ipynb` notebook pasand aaye, toh download-upload ke jhanjhat ke bina use direct Google Colab aur Drive mein save karne ka shortcut:
#
# ### 🔹 Step 1: URL Badlo, Colab me Kholo (Fastest)
# 1. Browser ke URL box mein jahan **`github.com`** likha hai, use badalkar **`githubtocolab.com`** kar do.
# 2. **Enter** maaro, notebook direct Google Colab mein khul jayegi.
#
# ---
#
# ### 🔹 Step 2: Google Drive me Permanent Save Karein
# Colab mein temporary khulne ke baad use apne Drive mein daalne ke liye:
# * Top-left corner mein **File** menu par click karein.
# * **Save a copy in Drive** (`Ctrl + S`) par click kar dein.
#
# > 📁 **Note:** Yeh notebook hamesha ke liye aapke Google Drive ke **"Colab Notebooks"** naam ke folder mein save ho jayegi, jahan aap ise jab chahein edit aur run kar sakte hain!

# %%
# 📊 Shortcut Note: GitHub se Direct CSV File Read Karna (No Download)

Agar GitHub par koi `.csv` file padi hai aur use direct `pd.read_csv()` mein load karna hai:

### 🔹 Step 1: GitHub par "Raw" Link Nikalein
1. GitHub par us CSV file ke page par jayein.
2. File ke upar right side mein ek **`Raw`** naam ka button dikhega, uspar click karein.
3. Ab browser ke address bar mein jo naya URL aayega (jo `https://raw.githubusercontent.com/...` se shuru hoga), use **Copy** karlein.

---

### 🔹 Step 2: Pandas mein Direct Paste Karein
Colab ke Code cell mein us copied link ko direct `pd.read_csv()` ke andar daal dein:

```python
import pandas as pd

# Raw URL ko yahan paste karein
url = '[https://raw.githubusercontent.com/username/repo/main/data.csv](https://raw.githubusercontent.com/username/repo/main/data.csv)'

# Direct load ho jayega, download ki koi jhanjhat nahi!
df = pd.read_csv(url)
df.head()

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                               api_url  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XOF  https://www.exchangerate-api.com
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
#
#                                        api_docs  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XOF  https://www.exchangerate-api.com/docs/free
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# Processing c:\users\91842\appdata\local\pip\cache\wheels\57\e4\98\5feafb5c393dd2540e44b064a6f95832990d543e5b4f53ea8f\mysql_connector-2.2.9-cp38-cp38-win_amd64.whl
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)

# %%
df
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
